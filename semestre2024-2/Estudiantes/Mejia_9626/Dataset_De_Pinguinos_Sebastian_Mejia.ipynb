# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# 1. ¿Cuántas especies diferentes de pingüinos hay en el dataset?

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
len(df.species.unique()) #numero total de especies
# Out:
# 3

# %% [markdown]
# 2. ¿Cuál es la longitud media del pico de los pingüinos de la especie Adelie?

# %%
tf = df["species"] == "Adelie"
mascara1 = df[tf]
mascara1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 147       3475.0  Female
# 148       3450.0  Female
# 149       3750.0    Male
# 150       3700.0  Female
# 151       4000.0    Male
#
# [152 rows x 7 columns]

# %%
mascara1 = mascara1.dropna()

# %%
mascara1['bill_length_mm'].mean() #Longitud media del pico de los pinguinos
# Out:
# 38.82397260273973

# %% [markdown]
# 3. ¿Cuál es la masa corporal promedio de los pingüinos de la especie Gentoo?

# %%
tf1 = df["species"] == "Gentoo"
mascara2 = df[tf1]
mascara2
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 220       4500.0  Female
# 221       5700.0    Male
# 222       4450.0  Female
# 223       5700.0    Male
# 224       5400.0    Male
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [124 rows x 7 columns]

# %%
mascara2 = mascara2.dropna()

# %%
mascara1['body_mass_g'].mean()
# Out:
# 3706.1643835616437

# %% [markdown]
# 4. ¿Cuál es la relación entre la longitud del pico y la masa corporal de los pingüinos?

# %%
df["Relacion"] = df["bill_length_mm"]/df["body_mass_g"]
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  Relacion
# 0         3750.0    Male  0.010427
# 1         3800.0  Female  0.010395
# 2         3250.0  Female  0.012400
# 3            NaN     NaN       NaN
# 4         3450.0  Female  0.010638
# ..           ...     ...       ...
# 339          NaN     NaN       NaN
# 340       4850.0  Female  0.009649
# 341       5750.0    Male  0.008765
# 342       5200.0  Female  0.008692
# 343       5400.0    Male  0.009241
#
# [344 rows x 8 columns]

# %% [markdown]
# 5. ¿Cuál es la isla con mayor número de pingüinos en el dataset?

# %%
df.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['island'].value_counts() #donde vemos que la mayor cantidad estan en Biscoe
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %% [markdown]
# 6. ¿Cuál es la desviación estándar de la longitud de la aleta de los pingüinos de la especie Chinstrap?

# %%
tf3 = df["species"] == "Chinstrap"
mascara3 = df[tf3].dropna()
mascara3
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Chinstrap  Dream            46.5           17.9              192.0
# 153  Chinstrap  Dream            50.0           19.5              196.0
# 154  Chinstrap  Dream            51.3           19.2              193.0
# 155  Chinstrap  Dream            45.4           18.7              188.0
# 156  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  Relacion
# 152       3500.0  Female  0.013286
# 153       3900.0    Male  0.012821
# 154       3650.0    Male  0.014055
# 155       3525.0  Female  0.012879
# 156       3725.0    Male  0.014148
# ..           ...     ...       ...
# 215       4000.0    Male  0.013950
# 216       3400.0  Female  0.012794
# 217       3775.0    Male  0.013139
# 218       4100.0    Male  0.012390
# 219       3775.0  Female  0.013298
#
# [68 rows x 8 columns]

# %%
mascara3['flipper_length_mm'].std()
# Out:
# 7.131894258578146

# %% [markdown]
# 7. ¿Qué pingüino tiene el pico más largo en el dataset y cuál es su especie?

# %%
df.loc[df['bill_length_mm'].idxmax()]
# Out:
# species                Gentoo
# island                 Biscoe
# bill_length_mm           59.6
# bill_depth_mm            17.0
# flipper_length_mm       230.0
# body_mass_g            6050.0
# sex                      Male
# Relacion             0.009851
# Name: 253, dtype: object

# %% [markdown]
# 8. ¿Cuál es la proporción de machos y hembras en la especie Adelie?

# %%
mascara1['sex'].value_counts()
# Out:
# sex
# Male      73
# Female    73
# Name: count, dtype: int64

# %% [markdown]
#  9. ¿Existe una correlación significativa entre la longitud del pico y la masa corporal en las diferentes especies de pingüinos?

# %%
df.groupby('species')[['bill_length_mm', 'body_mass_g']].corr(method='pearson')
# Out:
#                           bill_length_mm  body_mass_g
# species
# Adelie    bill_length_mm        1.000000     0.548866
#           body_mass_g           0.548866     1.000000
# Chinstrap bill_length_mm        1.000000     0.513638
#           body_mass_g           0.513638     1.000000
# Gentoo    bill_length_mm        1.000000     0.669166
#           body_mass_g           0.669166     1.000000

# %% [markdown]
# 10. ¿Cuál es la distribución de la masa corporal entre las especies de pingüinos?

# %%
sns.histplot(mascara1['body_mass_g'], bins=30, kde=False)
plt.title('Distribución De Masa')
plt.show()

# %%
sns.histplot(mascara2['body_mass_g'], bins=30, kde=False)
plt.title('Distribución De Masa')
plt.show()

# %%
sns.histplot(mascara3['body_mass_g'], bins=30, kde=False)
plt.title('Distribución De Masa')
plt.show()

# %% [markdown]
# 11. ¿Cuál es la longitud mínima y máxima de la aleta entre las tres especies de pingüinos?

# %%
df.loc[df['flipper_length_mm'].idxmax()]
# Out:
# species                Gentoo
# island                 Biscoe
# bill_length_mm           54.3
# bill_depth_mm            15.7
# flipper_length_mm       231.0
# body_mass_g            5650.0
# sex                      Male
# Relacion             0.009611
# Name: 283, dtype: object

# %%
df.loc[df['flipper_length_mm'].idxmin()]
# Out:
# species                Adelie
# island                 Biscoe
# bill_length_mm           37.9
# bill_depth_mm            18.6
# flipper_length_mm       172.0
# body_mass_g            3150.0
# sex                    Female
# Relacion             0.012032
# Name: 28, dtype: object

# %% [markdown]
# 12. ¿Cuántos pingüinos tienen una masa corporal superior a 5000 gramos?

# %%
tf4 = df["body_mass_g"] >= 5000
df[tf4]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# 227  Gentoo  Biscoe            46.7           15.3              219.0
# 229  Gentoo  Biscoe            46.8           15.4              215.0
# ..      ...     ...             ...            ...                ...
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  Relacion
# 221       5700.0    Male  0.008772
# 223       5700.0    Male  0.008772
# 224       5400.0    Male  0.008815
# 227       5200.0    Male  0.008981
# 229       5150.0    Male  0.009087
# ..           ...     ...       ...
# 335       5850.0    Male  0.009419
# 337       6000.0    Male  0.008133
# 341       5750.0    Male  0.008765
# 342       5200.0  Female  0.008692
# 343       5400.0    Male  0.009241
#
# [67 rows x 8 columns]

# %% [markdown]
# 13. ¿Cómo varía la longitud del pico entre las diferentes especies de pingüinos en las distintas islas?

# %%
df.groupby('species')['body_mass_g'].describe()
sns.boxplot(x='species', y='body_mass_g', data=df)
plt.title('Boxplot de la Masa Corporal por Especie')
plt.xlabel('Especie')
plt.ylabel('Masa Corporal (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# 14. ¿Cuál es la relación entre la longitud de la aleta y la masa corporal en los pingüinos de la especie Gentoo?

# %%
mascara2["Relacion Aleta/Masa"] = mascara2["flipper_length_mm"]/mascara2["body_mass_g"]
mascara2
# Out:
# <ipython-input-38-a2d9874d0c07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mascara2["Relacion Aleta/Masa"] = mascara2["flipper_length_mm"]/mascara2["body_mass_g"]
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 220  Gentoo  Biscoe            46.1           13.2              211.0
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 224  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  Relacion Aleta/Masa
# 220       4500.0  Female             0.046889
# 221       5700.0    Male             0.040351
# 222       4450.0  Female             0.047191
# 223       5700.0    Male             0.038246
# 224       5400.0    Male             0.039815
# ..           ...     ...                  ...
# 338       4925.0  Female             0.043452
# 340       4850.0  Female             0.044330
# 341       5750.0    Male             0.038609
# 342       5200.0  Female             0.040769
# 343       5400.0    Male             0.039444
#
# [119 rows x 8 columns]

# %% [markdown]
# 15. ¿Cuántos pingüinos tienen datos faltantes en alguna de sus características?

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# Relacion              2
# dtype: int64

# %% [markdown]
# 16. ¿Cuál es la isla con la mayor variación en la longitud del pico entre las tres especies de pingüinos?

# %%
df = df.dropna()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  Relacion
# 0         3750.0    Male  0.010427
# 1         3800.0  Female  0.010395
# 2         3250.0  Female  0.012400
# 4         3450.0  Female  0.010638
# 5         3650.0    Male  0.010767
# ..           ...     ...       ...
# 338       4925.0  Female  0.009584
# 340       4850.0  Female  0.009649
# 341       5750.0    Male  0.008765
# 342       5200.0  Female  0.008692
# 343       5400.0    Male  0.009241
#
# [333 rows x 8 columns]

# %%
desviacion_estandar = df.groupby(['species', 'island'])['bill_length_mm'].std()
desviacion_estandar.idxmax()
# Out:
# ('Chinstrap', 'Dream')

# %% [markdown]
# 17. ¿Cuál es la diferencia en masa corporal promedio entre machos y hembras de la especie Chinstrap?

# %%
promedio = mascara3.groupby('sex')['body_mass_g'].mean()
diferencia = promedio['Male'] - promedio['Female']
diferencia
# Out:
# 411.76470588235316

# %% [markdown]
# 18. ¿Qué especie de pingüino tiene la longitud de aleta promedio más alta?

# %%
promedio1 = df.groupby("species")["flipper_length_mm"].mean()
promedio1.idxmax()
# Out:
# 'Gentoo'

# %% [markdown]
# 19. ¿Cuál es la longitud del pico más pequeña registrada en el dataset y de qué especie es?

# %%
df.loc[df['bill_length_mm'].idxmin()]
# Out:
# species                Adelie
# island                  Dream
# bill_length_mm           32.1
# bill_depth_mm            15.5
# flipper_length_mm       188.0
# body_mass_g            3050.0
# sex                    Female
# Relacion             0.010525
# Name: 142, dtype: object

# %% [markdown]
# 20. ¿Cuál es la relación entre el sexo y la longitud de la aleta en los pingüinos de la especie Adelie?

# %%
estadisticas = mascara1.groupby('sex')['flipper_length_mm'].describe()
estadisticas
# Out:
#         count        mean       std    min    25%    50%    75%    max
# sex
# Female   73.0  187.794521  5.595035  172.0  185.0  188.0  191.0  202.0
# Male     73.0  192.410959  6.599317  178.0  189.0  193.0  197.0  210.0
